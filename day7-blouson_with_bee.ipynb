# %%
### 1. Users Data Structure

users = [
    {
        "id": 1,
        "username": "admin",
        "password": "admin123",
        "role": "admin"
    },
    {
        "id": 2,
        "username": "john",
        "password": "john123",
        "role": "customer"
    }
]

### 2. Products Data Structure

products = [
    {
        "id": 1,
        "name": "Laptop",
        "price": 999.99,
        "stock": 10
    },
    {
        "id": 2,
        "name": "Smartphone",
        "price": 499.99,
        "stock": 15
    }
]


### 3. Cart Data Structure

cart = [
    {
        "user_id": 2,
        "product_id": 1,
        "quantity": 2
    }
]


### 4. Orders Data Structure

orders = [
    {
        "id": 1,
        "user_id": 2,
        "items": [
            {
                "product_id": 1,
                "quantity": 2
            }
        ],
        "date": "2024-11-12 10:30:45",
        "total": 1999.98
    }
]

# %% [markdown]
# ### 3. Customer Menu After Login
# Expected Output:
#
# Welcome, john!
#
# 1. View Products
# 2. Add to Cart
# 3. View Cart
# 4. Checkout
# 5. Order History
# 6. Logout
#
# Enter your choice:

# %%
#3. Customer Menu After Login

def Menu_After_Login(users,products,cart,orders):
    main_menu = 7
    while True:
        main_menu = int(input("""
        Welcome, john!

            1. View Products
            2. Add to Cart
            3. View Cart
            4. Checkout
            5. Order History
            6. Logout
        
        Enter your choice:
                      """))
        if main_menu ==1:
            print(products[:])
        elif main_menu ==2:
            None #add
        elif main_menu ==3:
            print(cart[:])
        elif main_menu ==4:
            None #add
        elif main_menu ==5:
            None #add
        elif main_menu ==6:
            break
        else:
            print("you chose 1-6")
        

Menu_After_Login(users,products,cart,orders)
# Out:
# you chose 1-6
